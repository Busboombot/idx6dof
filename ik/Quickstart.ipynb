# %% [markdown]
# # IKpy Quick-start #

# %% [markdown]
# # Requirements

# %% [markdown]
# First, you need to install IKPy (see [installations instructions](https://github.com/Phylliade/ikpy)).
# You also need a URDF file.
# By default, we use the files provided in the [resources](https://github.com/Phylliade/ikpy/tree/master/resources) folder of the IKPy repo.

# %% [markdown]
# Import the IKPy module :

# %%
import ikpy
import numpy as np
from ikpy import plot_utils
# Out:
# /Volumes/Storage/proj/virt/idx6dof/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# The basic element of IKPy is the kinematic `Chain`.
# To create a chain from an URDF file :

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("../../resources/poppy_ergo.URDF")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-d46532b7526c> in <module>()
# ----> 1 my_chain = ikpy.chain.Chain.from_urdf_file("../../resources/poppy_ergo.URDF")
#
# /Volumes/Storage/proj/virt/idx6dof/lib/python2.7/site-packages/ikpy/chain.pyc in from_urdf_file(cls, urdf_file, base_elements, last_link_vector, base_element_type, active_links_mask, name)
#     121        :param string Name: The name of the Chain
#     122         """
# --> 123         links = URDF_utils.get_urdf_parameters(urdf_file, base_elements=base_elements, last_link_vector=last_link_vector, base_element_type=base_element_type)
#     124         # Add an origin link at the beginning
#     125         return cls([link_lib.OriginLink()] + links, active_links_mask=active_links_mask, name=name)
#
# /Volumes/Storage/proj/virt/idx6dof/lib/python2.7/site-packages/ikpy/URDF_utils.pyc in get_urdf_parameters(urdf_file, base_elements, last_link_vector, base_element_type)
#      93    :type last_link_vector: numpy.array
#      94     """
# ---> 95     tree = ET.parse(urdf_file)
#      96     root = tree.getroot()
#      97     base_elements = list(base_elements)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/xml/etree/ElementTree.pyc in parse(source, parser)
#    1180 def parse(source, parser=None):
#    1181     tree = ElementTree()
# -> 1182     tree.parse(source, parser)
#    1183     return tree
#    1184
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/xml/etree/ElementTree.pyc in parse(self, source, parser)
#     645         close_source = False
#     646         if not hasattr(source, "read"):
# --> 647             source = open(source, "rb")
#     648             close_source = True
#     649         try:
#
# IOError: [Errno 2] No such file or directory: '../../resources/poppy_ergo.URDF'

# %% [markdown]
# Note : as mentioned before, here we use a file in the resource folder.

# %% [markdown]
# # Inverse kinematics

# %% [markdown]
# In Inverse Kinematics, you want your kinematic chain to reach a 3D position in space.

# %% [markdown]
# To have a more general representation of position, IKPy works with homogeneous coordinates. It is a 4x4 matrix storing both position and orientation.
# Prepare your desired position as a 4x4 matrix. Here we only consider position, not orientation of the chain.

# %%
#target_vector = [ 0.1, -0.2, 0.1] 
target_vector = [ .5, .5, .5]
target_frame = np.eye(4)
target_frame[:3, 3] = target_vector

# %%
print("The angles of each joints are : ", my_chain.inverse_kinematics(target_frame))
# Out:
# ('The angles of each joints are : ', array([ 0.]))

# %% [markdown]
# You can check that the Inverse Kinematics is correct by comparing with the original position vector :

# %%
real_frame = my_chain.forward_kinematics(my_chain.inverse_kinematics(target_frame))
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_frame[:3, 3]))
# Out:
# Computed position vector : [ 0.  0.  0.], original position vector : [ 0.5  0.5  0.5]

# %% [markdown]
# # Plotting
# And finally plot the result :

# %% [markdown]
# (If the code below doesn't work, comment the `%maplotlib notebook` line, and uncomment the `%matplotlib inline` line)

# %%
# If there is a matplotlib error, uncomment the next line, and comment the line below it.
# %matplotlib inline
# %matplotlib notebook
import matplotlib.pyplot as plt
ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_frame), ax, target=target_vector)
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)
# Out:
# <img src="data:image/png;base64,...">
# (-0.1, 0.1)

# %% [markdown]
# You're done! Go to the [tutorials](https://github.com/Phylliade/ikpy/blob/master/tutorials/ikpy/getting_started.md) to understand the general concepts of the library.
