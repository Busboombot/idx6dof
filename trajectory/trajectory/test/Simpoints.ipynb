# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline
from trajectory import * 
import pandas as pd
from itertools import islice

# %%
ss = SimSegment(50000, 0, t=.01)
print(ss.initial_params())
list(ss)
# Out:
# (-250, 20.0, 5120)
# [StepParams(n=-250, tn=0.0, cn=20.0, ca1=0, xn=0, vn=50000, dir=1, tf=0.01, x=250),
#  StepParams(n=-249, tn=2e-05, cn=20.04, ca1=-0.04, xn=1, vn=49900, dir=1, tf=0.01, x=250),
#  StepParams(n=-248, tn=4e-05, cn=20.08, ca1=-0.04, xn=2, vn=49799, dir=1, tf=0.01, x=250),
#  StepParams(n=-247, tn=6e-05, cn=20.12, ca1=-0.04, xn=3, vn=49698, dir=1, tf=0.01, x=250),
#  StepParams(n=-246, tn=8e-05, cn=20.16, ca1=-0.04, xn=4, vn=49598, dir=1, tf=0.01, x=250),
#  StepParams(n=-245, tn=0.000101, cn=20.2, ca1=-0.04, xn=5, vn=49496, dir=1, tf=0.01, x=250),
#  StepParams(n=-244, tn=0.000121, cn=20.24, ca1=-0.04, xn=6, vn=49395, dir=1, tf=0.01, x=250),
#  StepParams(n=-243, tn=0.000141, cn=20.29, ca1=-0.04, xn=7, vn=49294, dir=1, tf=0.01, x=250),
#  StepParams(n=-242, tn=0.000161, cn=20.33, ca1=-0.04, xn=8, vn=49192, dir=1, tf=0.01, x=250),
#  StepParams(n=-241, tn=0.000182, cn=20.37, ca1=-0.04, xn=9, vn=49090, dir=1, tf=0.01, x=250),
# ...
